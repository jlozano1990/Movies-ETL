# %%
import json
import pandas as pd
import numpy as np
import re

# %%
file_dir = 'C:/Users/johnj/OneDrive/Documents/Data Analytics Coursework/Movies-ETL/'

# %%
with open(f'{file_dir}/wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
len(wiki_movies_raw)
# Out:
# 7311

# %%
# First 5 records
wiki_movies_raw[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$21.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/After_Dark,_My_Sweet',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098994/',
#   'title': 'After Dark, My Sweet',
#   'Directed by': 'James Foley',
#   'Produced by': ['Ric Kidney', 'Robert Redlin'],
#   'Screenplay by': ['James Foley', 'Robert Redlin'],
#   'Based on': ['the novel', 'After Dark, My Sweet', 'by', 'Jim Thompson'],
#   'Starring': ['Jason Patric',
#    'Rachel Ward',
#    'Bruce Dern',
#    'George Dickerson'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Mark Plummer',
#   'Edited by': 'Howard E. Smith',
#   'Productioncompany ': 'Avenue Pictures',
#   'Distributed by': 'Avenue Pictures',
#   'Release date': ['May 17, 1990',
#    '(',
#    '1990-05-17',
#    ')',
#    '(Cannes Film Market)',
#    'August 24, 1990',
#    '(',
#    '1990-08-24',
#    ')',
#    '(United States)'],
#   'Running time': '114 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$6 million',
#   'Box office': '$2.7 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Air_America_(film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099005/',
#   'title': 'Air America',
#   'Directed by': 'Roger Spottiswoode',
#   'Produced by': 'Daniel Melnick',
#   'Screenplay by': ['John Eskow', 'Richard Rush'],
#   'Based on': ['Air America', 'by', 'Christopher Robbins'],
#   'Starring': ['Mel Gibson',
#    'Robert Downey Jr.',
#    'Nancy Travis',
#    'David Marshall Grant',
#    'Lane Smith'],
#   'Music by': 'Charles Gross',
#   'Cinematography': 'Roger Deakins',
#   'Edited by': ['John Bloom', 'Lois Freeman-Fox'],
#   'Productioncompany ': ['Carolco Pictures', 'IndieProd Company'],
#   'Distributed by': 'TriStar Pictures',
#   'Release date': ['August 10, 1990', '(', '1990-08-10', ')'],
#   'Running time': '113 minutes',
#   'Country': 'United States',
#   'Language': ['English', 'Lao'],
#   'Budget': '$35 million',
#   'Box office': '$57,718,089'},
#  {'url': 'https://en.wikipedia.org/wiki/Alice_(1990_film)',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099012/',
#   'title': 'Alice',
#   'Directed by': 'Woody Allen',
#   'Produced by': 'Robert Greenhut',
#   'Written by': 'Woody Allen',
#   'Starring': ['Alec Baldwin',
#    'Blythe Danner',
#    'Judy Davis',
#    'Mia Farrow',
#    'William Hurt',
#    'Keye Luke',
#    'Joe Mantegna',
#    'Bernadette Peters'],
#   'Cinematography': 'Carlo Di Palma',
#   'Edited by': 'Susan E. Morse',
#   'Distributed by': 'Orion Pictures',
#   'Release date': ['December 25, 1990', '(', '1990-12-25', ')'],
#   'Running time': '106 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$12 million',
#   'Box office': '$7,331,647'},
#  {'url': 'https://en.wikipedia.org/wiki/Almost_an_Angel',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0099018/',
#   'title': 'Almost an Angel',
#   'Directed by': 'John Cornell',
#   'Produced by': 'John Cornell',
#   'Written by': 'Paul Hogan',
#   'Starring': ['Paul Hogan', 'Elias Koteas', 'Linda Kozlowski'],
#   'Music by': 'Maurice Jarre',
#   'Cinematography': 'Russell Boyd',
#   'Edited by': 'David Stiven',
#   'Distributed by': 'Paramount Pictures',
#   'Release date': 'December 19, 1990',
#   'Running time': '95 minutes',
#   'Country': 'US',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$6,939,946 (USA)'}]

# %%
# Last 5 records
wiki_movies_raw[-5:]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Holmes_%26_Watson',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt1255919/',
#   'title': 'Holmes & Watson',
#   'Directed by': 'Etan Cohen',
#   'Produced by': ['Will Ferrell',
#    'Adam McKay',
#    'Jimmy Miller',
#    'Clayton Townsend'],
#   'Screenplay by': 'Etan Cohen',
#   'Based on': ['Sherlock Holmes',
#    'and',
#    'Dr. Watson',
#    'by',
#    'Sir Arthur Conan Doyle'],
#   'Starring': ['Will Ferrell',
#    'John C. Reilly',
#    'Rebecca Hall',
#    'Rob Brydon',
#    'Steve Coogan',
#    'Ralph Fiennes'],
#   'Music by': 'Mark Mothersbaugh',
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Dean Zimmerman',
#   'Productioncompanies ': ['Columbia Pictures',
#    'Gary Sanchez Productions',
#    'Mosaic Media Group',
#    'Mimran Schur Pictures'],
#   'Distributed by': 'Sony Pictures Releasing',
#   'Release date': ['December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '90 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$42 million',
#   'Box office': '$41.9 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Vice_(2018_film)',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt6266538/',
#   'title': 'Vice',
#   'Directed by': 'Adam McKay',
#   'Produced by': ['Brad Pitt',
#    'Dede Gardner',
#    'Jeremy Kleiner',
#    'Kevin J. Messick',
#    'Will Ferrell',
#    'Adam McKay'],
#   'Written by': 'Adam McKay',
#   'Starring': ['Christian Bale',
#    'Amy Adams',
#    'Steve Carell',
#    'Sam Rockwell',
#    'Tyler Perry',
#    'Alison Pill',
#    'Lily Rabe',
#    'Jesse Plemons'],
#   'Music by': 'Nicholas Britell',
#   'Cinematography': 'Greig Fraser',
#   'Edited by': 'Hank Corwin',
#   'Productioncompany ': ['Plan B Entertainment',
#    'Gary Sanchez Productions',
#    'Annapurna Pictures'],
#   'Distributed by': 'Mirror Releasing',
#   'Release date': ['December 11, 2018',
#    '(',
#    '2018-12-11',
#    ')',
#    '(',
#    'Samuel Goldwyn Theater',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '132 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$60 million',
#   'Box office': '$76.1 million'},
#  {'url': 'https://en.wikipedia.org/wiki/On_the_Basis_of_Sex',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt4669788/',
#   'title': 'On the Basis of Sex',
#   'Directed by': 'Mimi Leder',
#   'Produced by': 'Robert W. Cort',
#   'Written by': 'Daniel Stiepleman',
#   'Starring': ['Felicity Jones',
#    'Armie Hammer',
#    'Justin Theroux',
#    'Sam Waterston',
#    'Kathy Bates'],
#   'Music by': 'Mychael Danna',
#   'Cinematography': 'Michael Grady',
#   'Edited by': 'Michelle Tesoro',
#   'Productioncompanies ': ['Focus Features',
#    '[1]',
#    'Participant Media',
#    '[1]',
#    'Robert Cort Productions',
#    '[1]',
#    'Alibaba Pictures',
#    '[2]'],
#   'Distributed by': 'Focus Features',
#   'Release date': ['November 8, 2018',
#    '(',
#    '2018-11-08',
#    ')',
#    '(',
#    'AFI Fest',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '120 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$38.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Destroyer_(2018_film)',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt7137380/',
#   'title': 'Destroyer',
#   'Directed by': 'Karyn Kusama',
#   'Produced by': ['Fred Berger', 'Phil Hay', 'Matt Manfredi'],
#   'Written by': ['Phil Hay', 'Matt Manfredi'],
#   'Starring': ['Nicole Kidman',
#    'Sebastian Stan',
#    'Toby Kebbell',
#    'Tatiana Maslany',
#    'Bradley Whitford',
#    'Jade Pettyjohn',
#    'Scoot McNairy'],
#   'Music by': 'Theodore Shapiro',
#   'Cinematography': 'Julie Kirkwood',
#   'Edited by': 'Plummy Tucker',
#   'Productioncompany ': ['30West',
#    'Automatik Entertainment',
#    'Annapurna Pictures'],
#   'Distributed by': 'Mirror Releasing',
#   'Release date': ['August 31, 2018',
#    '(',
#    '2018-08-31',
#    ')',
#    '(',
#    'Telluride',
#    ')',
#    'December 25, 2018',
#    '(',
#    '2018-12-25',
#    ')',
#    '(United States)'],
#   'Running time': '123 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$9 million',
#   'Box office': '$5.5 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Black_Mirror:_Bandersnatch',
#   'year': 2018,
#   'imdb_link': 'https://www.imdb.com/title/tt9495224/',
#   'title': 'Bandersnatch',
#   'Directed by': 'David Slade',
#   'Produced by': 'Russell McLean',
#   'Written by': 'Charlie Brooker',
#   'Starring': ['Fionn Whitehead',
#    'Will Poulter',
#    'Craig Parkinson',
#    'Alice Lowe',
#    'Asim Chaudhry'],
#   'Music by': 'Brian Reitzell',
#   'Cinematography': ['Aaron Morton', 'Jake Polonsky'],
#   'Edited by': 'Tony Kearns',
#   'Productioncompany ': ['House of Tomorrow', 'Netflix'],
#   'Distributed by': 'Netflix',
#   'Release date': ['28 December 2018', '(', '2018-12-28', ')'],
#   'Running time': 'Variable; 90 minutes for default path',
#   'Country': 'United Kingdom',
#   'Language': 'English'}]

# %%
# Some records in the middle
wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
#   'Starring': ['Marc Rozendaal',
#    'Michael Silverman',
#    'David Warshofsky',
#    'Audra McDonald',
#    'Lois Smith'],
#   'Music by': ['Prince Paul', 'and', 'Don Newkirk'],
#   'Cinematography': 'Ben Kutchins',
#   'Edited by': 'Stephanie Sterner',
#   'Distributed by': 'Showtime Networks',
#   'Release date': ['January 16, 2004', '(', '2004-01-16', ')'],
#   'Running time': '93 minutes',
#   'Country': 'United States',
#   'Language': 'English'},
#  {'url': 'https://en.wikipedia.org/wiki/Beyond_the_Sea_(2004_film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0363473/',
#   'title': 'Beyond the Sea',
#   'Directed by': 'Kevin Spacey',
#   'Produced by': ['Kevin Spacey',
#    'Phillip Barry',
#    'Dana Brunetti',
#    'Arthur Friedman',
#    'Jan Fantl',
#    'Andy Paterson'],
#   'Written by': ['Lewis Colick', 'Kevin Spacey'],
#   'Starring': ['Kevin Spacey', 'Kate Bosworth', 'Bob Hoskins', 'John Goodman'],
#   'Music by': 'Bobby Darin',
#   'Cinematography': 'Eduardo Serra',
#   'Edited by': 'Trevor Waite',
#   'Productioncompany ': 'Trigger Street Productions',
#   'Distributed by': ['Lionsgate Films',
#    '(USA)',
#    'Entertainment Film Distributors',
#    '(UK)',
#    'GAGA',
#    '(Japan)',
#    'Maple Pictures',
#    '(Canada)'],
#   'Release date': ['December 17, 2004', '(', '2004-12-17', ')'],
#   'Running time': '118 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$25 million',
#   'Box office': '$8.4 million'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Big_Bounce_(2004_film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315824/',
#   'title': 'The Big Bounce',
#   'Directed by': 'George Armitage',
#   'Produced by': ['George Armitage', 'Steve Bing'],
#   'Screenplay by': 'Sebastian Gutierrez',
#   'Based on': ['The Big Bounce', 'by', 'Elmore Leonard'],
#   'Starring': ['Owen Wilson',
#    'Charlie Sheen',
#    'Morgan Freeman',
#    'Sara Foster',
#    'Gary Sinise'],
#   'Music by': 'George S. Clinton',
#   'Cinematography': 'Jeffrey L. Kimball',
#   'Edited by': 'Barry Malkin',
#   'Productioncompany ': 'Shangri-La Entertainment',
#   'Distributed by': 'Warner Bros. Pictures',
#   'Release date': ['January 30, 2004', '(', '2004-01-30', ')'],
#   'Running time': '88 minutes',
#   'Language': 'English',
#   'Budget': '$50 million',
#   'Box office': '$6.8 million'},
#  {'url': 'https://en.wikipedia.org/wiki/Birth_(film)',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0337876/',
#   'title': 'Birth',
#   'Directed by': 'Jonathan Glazer',
#   'Produced by': ['Lizie Gower', 'Nick Morris', 'Jean-Louis Piel'],
#   'Written by': ['Jean-Claude Carrière', 'Milo Addica', 'Jonathan Glazer'],
#   'Starring': ['Nicole Kidman',
#    'Cameron Bright',
#    'Danny Huston',
#    'Lauren Bacall'],
#   'Music by': 'Alexandre Desplat',
#   'Cinematography': 'Harris Savides',
#   'Edited by': ['Sam Sneade', 'Claus Wehlisch'],
#   'Distributed by': 'New Line Cinema',
#   'Release date': ['November 8, 2004', '(', '2004-11-08', ')'],
#   'Running time': '96 minutes',
#   'Country': 'United States',
#   'Language': 'English',
#   'Budget': '$20 million',
#   'Box office': '$23.9 million'}]

# %%
kaggle_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings.csv')

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 4413348    45589      661     3.0  1330067352
# 11940243  123807     8360     5.0  1138899025
# 18614823  193271     2710     2.0   993180217
# 18383114  190784    97306     3.5  1353752237
# 4696925    48271     1095     4.0  1202929158

# %%
wiki_movies_df = pd.DataFrame(wiki_movies_raw)

# %%
wiki_movies_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Predecessor  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...         NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...         NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...         NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...         NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...         NaN
#
#   Founders Area served Products Services Russian Hebrew Revenue  \
# 0      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 1      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 2      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 3      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 4      NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#   Operating income Polish
# 0              NaN    NaN
# 1              NaN    NaN
# 2              NaN    NaN
# 3              NaN    NaN
# 4              NaN    NaN
#
# [5 rows x 193 columns]

# %%
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
#  'Cover artist',
#  'Series',
#  'Set in',
#  'Adaptation by',
#  'Suggested by',
#  'Biographical data',
#  'Born',
#  'Died',
#  'Resting place',
#  'Occupation',
#  'Years active',
#  'Spouse(s)',
#  'Children',
#  'Parent(s)',
#  'Genres',
#  'Instruments',
#  'Labels',
#  'Website',
#  'Traditional',
#  'Mandarin',
#  'Type',
#  'Industry',
#  'Fate',
#  'Founded',
#  'Founder',
#  'Headquarters',
#  'Parent',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
#  'Label',
#  'Director',
#  'Producer',
#  'Area',
#  'Coordinates',
#  'Status',
#  'Opening date',
#  'Closing date',
#  'Replaced',
#  'Replaced by',
#  'Name',
#  'Attraction type',
#  'Music',
#  'Duration',
#  'Simplified Chinese',
#  'Traditional Chinese',
#  'Hanyu Pinyin',
#  'Literal meaning',
#  'Transcriptions',
#  'Bopomofo',
#  'Gwoyeu Romatzyh',
#  'Wade–Giles',
#  'IPA',
#  'Yale Romanization',
#  'Jyutping',
#  'Hokkien POJ',
#  'Animation by',
#  'Color process',
#  'Engine(s)',
#  'Genre(s)',
#  'Actor control',
#  'Production company',
#  'Release(s)',
#  'Format(s)',
#  'Simplified',
#  'Characters',
#  'Date premiered',
#  'Place premiered',
#  'Setting',
#  'Original language',
#  'Subject',
#  'Published',
#  'Dewey Decimal',
#  'Text',
#  'Illustrator',
#  'Original title',
#  'Published in English',
#  'French',
#  'Developed by',
#  'Ending theme',
#  'No. of seasons',
#  'Nationality',
#  'Portrayed by',
#  'Alias',
#  'Species',
#  'Gender',
#  'Family',
#  'Alma mater',
#  'Camera setup',
#  'Novel(s)',
#  'Comics',
#  'Film(s)',
#  'Screen story by',
#  'Hangul',
#  'Revised Romanization',
#  'McCune–Reischauer',
#  'Developer(s)',
#  'Publisher(s)',
#  'Designer(s)',
#  'Programmer(s)',
#  'Artist(s)',
#  'Writer(s)',
#  'Engine',
#  'Platform(s)',
#  'Release',
#  'Mode(s)',
#  'Original work',
#  'Television series',
#  'Japanese',
#  'Hepburn',
#  'Literally',
#  'Cantonese',
#  'Full name',
#  'Height',
#  'Seasons',
#  'Chinese',
#  'Other names',
#  'Relatives',
#  'Yiddish',
#  'Formerly',
#  'Key people',
#  'Total assets',
#  'Owner',
#  'Number of employees',
#  'Divisions',
#  'Subsidiaries',
#  'Arabic',
#  'Romanized',
#  'Predecessor',
#  'Founders',
#  'Area served',
#  'Products',
#  'Services',
#  'Russian',
#  'Hebrew',
#  'Revenue',
#  'Operating income',
#  'Polish']

# %%
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]
len(wiki_movies)
# Out:
# 7076

# %%
wiki_clean_df = pd.DataFrame(wiki_movies)

# %%
wiki_clean_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# 2  Roger Spottiswoode               Daniel Melnick
# 3         Woody Allen              Robert Greenhut
# 4        John Cornell                 John Cornell
#
#                                 Screenplay by                     Story by  \
# 0  [David Arnott, James Cappe, Daniel Waters]  [David Arnott, James Cappe]
# 1                [James Foley, Robert Redlin]                          NaN
# 2                  [John Eskow, Richard Rush]                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring  ... Hepburn Literally  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  ...     NaN       NaN
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...  ...     NaN       NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...  ...     NaN       NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...  ...     NaN       NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]  ...     NaN       NaN
#
#   Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew Polish
# 0       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 1       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 2       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 3       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
# 4       NaN     NaN     NaN    NaN       NaN     NaN    NaN    NaN
#
# [5 rows x 75 columns]

# %%
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles
            
            
            
    return movie

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]
# Out:
#                                                   url    year  \
# 7060  https://en.wikipedia.org/wiki/The_Insult_(film)  2018.0
# 7293   https://en.wikipedia.org/wiki/Capernaum_(film)  2018.0
#
#                                   imdb_link       title    Directed by  \
# 7060  https://www.imdb.com/title/tt7048622/  The Insult   Ziad Doueiri
# 7293  https://www.imdb.com/title/tt8267604/   Capernaum  Nadine Labaki
#
#                                             Produced by  \
# 7060  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 7293                    [Michel Merkt, Khaled Mouzanar]
#
#                                           Screenplay by  \
# 7060                                                NaN
# 7293  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
#
#                                                Story by Based on  \
# 7060                                                NaN      NaN
# 7293  [Georges Khabbaz, Nadine Labaki, Michelle Kese...      NaN
#
#                                                Starring  ... Predecessor  \
# 7060                       [Adel Karam, Kamel El Basha]  ...         NaN
# 7293  [Zain Al Rafeea, Yordanos Shiferaw, Boluwatife...  ...         NaN
#
#      Founders Area served Products Services Russian Hebrew Revenue  \
# 7060      NaN         NaN      NaN      NaN     NaN    NaN     NaN
# 7293      NaN         NaN      NaN      NaN     NaN    NaN     NaN
#
#      Operating income Polish
# 7060              NaN    NaN
# 7293              NaN    NaN
#
# [2 rows x 193 columns]

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]['url']
# Out:
# 7060    https://en.wikipedia.org/wiki/The_Insult_(film)
# 7293     https://en.wikipedia.org/wiki/Capernaum_(film)
# Name: url, dtype: object

# %%
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Actor control',
#  'Adaptation by',
#  'Alias',
#  'Alma mater',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Area',
#  'Area served',
#  'Artist(s)',
#  'Attraction type',
#  'Audio format',
#  'Author',
#  'Based on',
#  'Biographical data',
#  'Bopomofo',
#  'Born',
#  'Box office',
#  'Budget',
#  'Camera setup',
#  'Cantonese',
#  'Characters',
#  'Children',
#  'Chinese',
#  'Cinematography',
#  'Closing date',
#  'Color process',
#  'Comics',
#  'Composer(s)',
#  'Coordinates',
#  'Country',
#  'Country of origin',
#  'Cover artist',
#  'Created by',
#  'Date premiered',
#  'Designer(s)',
#  'Developed by',
#  'Developer(s)',
#  'Dewey Decimal',
#  'Died',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Divisions',
#  'Duration',
#  'Edited by',
#  'Editor(s)',
#  'Ending theme',
#  'Engine',
#  'Engine(s)',
#  'Executive producer(s)',
#  'Family',
#  'Fate',
#  'Film(s)',
#  'Followed by',
#  'Format(s)',
#  'Formerly',
#  'Founded',
#  'Founder',
#  'Founders',
#  'French',
#  'Full name',
#  'Gender',
#  'Genre',
#  'Genre(s)',
#  'Genres',
#  'Gwoyeu Romatzyh',
#  'Hangul',
#  'Hanyu Pinyin',
#  'Headquarters',
#  'Hebrew',
#  'Height',
#  'Hepburn',
#  'Hokkien POJ',
#  'IPA',
#  'ISBN',
#  'Illustrator',
#  'Industry',
#  'Instruments',
#  'Japanese',
#  'Jyutping',
#  'Key people',
#  'LC Class',
#  'Label',
#  'Labels',
#  'Language',
#  'Length',
#  'Literal meaning',
#  'Literally',
#  'Mandarin',
#  'McCune–Reischauer',
#  'Media type',
#  'Mode(s)',
#  'Music',
#  'Music by',
#  'Name',
#  'Narrated by',
#  'Nationality',
#  'No. of episodes',
#  'No. of seasons',
#  'Novel(s)',
#  'Number of employees',
#  'OCLC',
#  'Occupation',
#  'Opening date',
#  'Opening theme',
#  'Operating income',
#  'Original language',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Original title',
#  'Original work',
#  'Other names',
#  'Owner',
#  'Pages',
#  'Parent',
#  'Parent(s)',
#  'Picture format',
#  'Place premiered',
#  'Platform(s)',
#  'Polish',
#  'Portrayed by',
#  'Preceded by',
#  'Predecessor',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Products',
#  'Programmer(s)',
#  'Publication date',
#  'Published',
#  'Published in English',
#  'Publisher',
#  'Publisher(s)',
#  'Recorded',
#  'Relatives',
#  'Release',
#  'Release date',
#  'Release(s)',
#  'Released',
#  'Replaced',
#  'Replaced by',
#  'Resting place',
#  'Revenue',
#  'Revised Romanization',
#  'Romanized',
#  'Running time',
#  'Russian',
#  'Screen story by',
#  'Screenplay by',
#  'Seasons',
#  'Series',
#  'Services',
#  'Set in',
#  'Setting',
#  'Simplified',
#  'Simplified Chinese',
#  'Species',
#  'Spouse(s)',
#  'Starring',
#  'Status',
#  'Story by',
#  'Subject',
#  'Subsidiaries',
#  'Suggested by',
#  'Television series',
#  'Text',
#  'Theme music composer',
#  'Total assets',
#  'Traditional',
#  'Traditional Chinese',
#  'Transcriptions',
#  'Type',
#  'Venue',
#  'Voices of',
#  'Wade–Giles',
#  'Website',
#  'Writer(s)',
#  'Written by',
#  'Yale Romanization',
#  'Years active',
#  'Yiddish',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
for i in sorted(wiki_movies_df.columns):
    print (wiki_movies_df[i].value_counts())
    print ("")
# Out:
# [Heath Brown, Eric Fowler, Chris Birke, Pyoveli]    1
# Name: Actor control, dtype: int64
#
# [John L. Balderston, Paul Perez, Daniel Moore]    1
# Michael McDowell                                  1
# Name: Adaptation by, dtype: int64
#
# Quincy Magoo    1
# Name: Alias, dtype: int64
#
# Loyola Marymount University    1
# Rutgers University             1
# Name: Alma mater, dtype: int64
#
# [Eyes on the Prize I, Eyes on the Prize II]    1
# Detonator II: Night Watch                      1
# Name: Also known as, dtype: int64
#
# [Andreas Deja, Gary Dunn, Deboissy Sylvain]                                                                                                                                                                                                                                               1
# [Joe Achorn, Edy Benjamin, Munir Bhatti, Thomas E. Decker, Patrick Gleeson, Duane Gretsky, John Hinshelwood, Martin Hopkins, Chuck Jones, Warren O'Neill, Jill Petrilak, Claude Raynes, Herman Sharaf, Bill Snelgrove, Darrell Van Citters, Dean Wellins, Greg Whittaker, Cory Wilson]    1
# Name: Animation by, dtype: int64
#
# کفرناحوم‎      1
# قضية رقم ٢٣    1
# Name: Arabic, dtype: int64
#
# Discoveryland    1
# Name: Area, dtype: int64
#
# Worldwide    3
# Name: Area served, dtype: int64
#
# Angie Radwan-Pytlewski    1
# Name: Artist(s), dtype: int64
#
# [3D film, with special effects]    1
# Name: Attraction type, dtype: int64
#
# Stereo             48
# Dolby               6
# [Ultra, Stereo]     4
# Mono                4
# Dolby SR            2
# Name: Audio format, dtype: int64
#
# [Vincent Bugliosi, and, Bruce Henderson]    1
# Thomas Hardy                                1
# Lewis Carroll                               1
# Patricia Highsmith                          1
# John le Carré                               1
# Tony Hillerman                              1
# Zane Grey                                   1
# John Berendt                                1
# Jules Verne                                 1
# Virginia Woolf                              1
# Henry James                                 1
# Daniel Defoe                                1
# Name: Author, dtype: int64
#
# [Star Trek, by, Gene Roddenberry]                                 8
# [Teenage Mutant Ninja Turtles, by, Kevin Eastman, Peter Laird]    6
# [Mission: Impossible, by, Bruce Geller]                           6
# [Transformers, by, Hasbro]                                        6
# [Characters, by, George Lucas]                                    5
#                                                                  ..
# [Winnie-the-Pooh, by, A. A. Milne]                                1
# [Clear and Present Danger, by, Tom Clancy]                        1
# [All the Way, by Andy Behrens]                                    1
# [Anaconda, by, Hans Bauer, Jim Cash, and, Jack Epps Jr.]          1
# [Angry Birds, by, Rovio Entertainment]                            1
# Name: Based on, Length: 1986, dtype: int64
#
# [Biographical data, Born, Francis Albert Sinatra, (, 1915-12-12, ), December 12, 1915, Hoboken, New Jersey, , U.S., Died, May 14, 1998, (1998-05-14), (aged 82), Los Angeles, California, , U.S., Resting place, Desert Memorial Park, ,, Cathedral City, California, , U.S., Occupation, Singer, actor, producer, Years active, 1935–95, Spouse(s), Nancy Barbato, (, m., 1939, ;, div., 1951, ), Ava Gardner, (, m., 1951;, div., 1957), Mia Farrow, (, m., 1966, ;, div., 1968), Barbara Marx, (, m., 1976, ), Children, Nancy, Frank Jr., Tina, Parent(s), Antonino Martino Sinatra, Natalina Garaventa, Musical career, Genres, Traditional pop, easy listening, jazz, swing, vocal jazz, Instruments, Vocals, Labels, RCA Victor, Columbia, Capitol, Reprise, Warner Bros., Website, sinatra, .com]    1
# Name: Biographical data, dtype: int64
#
# ㄊㄧㄢ   ㄢ   ㄇㄣˊ    1
# Name: Bopomofo, dtype: int64
#
# [Francis Albert Sinatra, (, 1915-12-12, ), December 12, 1915, Hoboken, New Jersey, , U.S.]                   1
# [(, 1963-01-04, ), 4 January 1963, (age 56), Cambrai, ,, Nord, ,, France]                                    1
# [Étienne Comar in 2017, (, 1965-01-25, ), 25 January 1965, (age 54), Paris, , France]                        1
# [Scott Clinton Reeves, (, 1986-03-21, ), March 21, 1986, (age 33), Monterey, California, , U.S.]             1
# [(, 1995-02-22, ), February 22, 1995, (age 24), North Carolina, , U.S.]                                      1
# [(, 1963-12-05, ), 5 December 1963, (age 55), Cheltenham, , England]                                         1
# [(, 1984-09-14, ), September 14, 1984, (age 34), Davenport, Iowa, , U.S.]                                    1
# [Marvin Earl Roberts, (, 1935-05-14, ), May 14, 1935, (age 84), Salinas, ,, California, ,, United States]    1
# Name: Born, dtype: int64
#
# $2 million        18
# $10 million       16
# $4 million        13
# $1.8 million      13
# $5 million        12
#                   ..
# $309.4 million     1
# $156,996           1
# $68,945            1
# $37.5 million      1
# $9,448,082         1
# Name: Box office, Length: 3657, dtype: int64
#
# $20 million                  210
# $30 million                  180
# $25 million                  175
# $10 million                  147
# $40 million                  142
#                             ...
# [$175–200, million, [3]]       1
# $200–317 million               1
# US$17,000,000 (estimated)      1
# US$30 million                  1
# $19.4 million                  1
# Name: Budget, Length: 869, dtype: int64
#
# Andrew McDonnell    1
# Name: Camera setup, dtype: int64
#
# [Jip, 6, Man, 6, Saam, 1]    1
# Name: Cantonese, dtype: int64
#
# [Jake, Maggie, Karen, Julie, Edith, Molly, Sheila]                               1
# [Mary Cavan Tyrone, James Tyrone, Edmund Tyrone, James Tyrone, Jr., Cathleen]    1
# Name: Characters, dtype: int64
#
# [Nancy, Frank Jr., Tina]    1
# Name: Children, dtype: int64
#
# 摇滚藏獒    1
# Name: Chinese, dtype: int64
#
# Roger Deakins                            38
# Dean Semler                              35
# Robert Elswit                            35
# Oliver Wood                              34
# Mark Irwin                               34
#                                          ..
# Art Clokey                                1
# Aleksei Rodionov                          1
# [Steven Bernstein, ,, ASC]                1
# Francisco Gonzalez                        1
# [Alexander Gruszynski, (live-action)]     1
# Name: Cinematography, Length: 2002, dtype: int64
#
# May 3, 2010    1
# Name: Closing date, dtype: int64
#
# Technicolor    1
# Name: Color process, dtype: int64
#
# Comic books    1
# Name: Comics, dtype: int64
#
# [Alex Goodman, Bruce Broughton, Thom Harp, Steve Nelson]    1
# J. A. C. Redford                                            1
# Jeremy Soule                                                1
# Hal Lindes                                                  1
# David E. Cole                                               1
# Steven Bernstein                                            1
# Kevin Kiner                                                 1
# Steve Goldstein                                             1
# Eduard Artemyev                                             1
# Richard Bellis                                              1
# [Jim Goodwin, Richard McHugh, Mike Slamer]                  1
# Name: Composer(s), dtype: int64
#
# [48°52′29″N, 2°46′48″E, ﻿ / ﻿, 48.8748°N 2.7799°E, ﻿ /, 48.8748; 2.7799]    1
# Name: Coordinates, dtype: int64
#
# United States                                       5465
# [United Kingdom, United States]                      123
# [United States, Canada]                               57
# [United States, United Kingdom]                       54
# United Kingdom                                        45
#                                                     ...
# [France, Italy, United Kingdom, United States]         1
# [United Kingdom, United States, France, Germany]       1
# [India, United Kingdom, Germany, Japan, [1]]           1
# [South Africa, [1], United States, [1]]                1
# [United Kingdom, India, United States]                 1
# Name: Country, Length: 534, dtype: int64
#
# United States                        143
# USA                                    3
# United Kingdom                         2
# [United States, Canada]                2
# [United Kingdom, United States]        1
# Germany/Italy/United States            1
# Canada                                 1
# UK / US                                1
# [United States, United Kingdom]        1
# [United States, Australia]             1
# [Germany, United States, Austria]      1
# United States/Australia                1
# Name: Country of origin, dtype: int64
#
# Myers & Noftsinger    1
# Graham Miller         1
# Wendell Galloway      1
# Name: Cover artist, dtype: int64
#
# Kenneth Johnson                                                 4
# [John William Corrington, (novel)]                              1
# David McCullough                                                1
# Gary Larson                                                     1
# Paul Abbott                                                     1
# James DeMonaco                                                  1
# [Sony Pictures Entertainment, A&E Television Networks]          1
# [Millard Kaufman, John Hubley, Willis Pyle, [1], Sherm Glas]    1
# G.D. Gearino (novel)                                            1
# [Marty Isenberg, Robert N. Skir, David Wise]                    1
# [Willa Cather, (novel)]                                         1
# Name: Created by, dtype: int64
#
# [March 24, 1992, (, 1992-03-24, )]      1
# 2 February 1956                         1
# [January 17, 2002, (, 2002-01-17, )]    1
# Name: Date premiered, dtype: int64
#
# Josh Mosqueira    1
# Name: Designer(s), dtype: int64
#
# [Marty Isenberg, Robert N. Skir, David Wise, Gordon Kent]    1
# Name: Developed by, dtype: int64
#
# Relic Entertainment    1
# Name: Developer(s), dtype: int64
#
# 813/.5/4        1
# 823.5           1
# 823/.912 20     1
# 975.8/724 20    1
# Name: Dewey Decimal, dtype: int64
#
# [May 14, 1998, (1998-05-14), (aged 82), Los Angeles, California, , U.S.]    1
# Name: Died, dtype: int64
# Steven Soderbergh        26
# Woody Allen              26
# Clint Eastwood           22
# Spike Lee                20
# Tyler Perry              19
#                          ..
# Nicholas Racz             1
# Bayer Mack                1
# Christopher Coppola       1
# Todd Strauss-Schulson     1
# H. Gordon Boos            1
# Name: Directed by, Length: 3580, dtype: int64
#
# Rocky Schenck         1
# Mark "Aldo" Miceli    1
# Name: Director, dtype: int64
#
# 20th Century Fox                                                   403
# Universal Pictures                                                 385
# Buena Vista Pictures                                               316
# Warner Bros. Pictures                                              306
# Paramount Pictures                                                 300
#                                                                   ...
# Brave New Films                                                      1
# [20th Century Fox Home Entertainment, Freestyle Releasing, [1]]      1
# [WWE Studios, BH Tilt]                                               1
# [20th Century Fox, (United Kingdom)]                                 1
# Nu Image Films                                                       1
# Name: Distributed by, Length: 1656, dtype: int64
#
# HBO                                      18
# CBS                                      13
# NBC                                      12
# ABC                                      10
# Buena Vista Television                   10
#                                          ..
# MCA TV                                    1
# Sonar Entertainment                       1
# Hallmark Films                            1
# NBC Universal Television Distribution     1
# [CBS, King Features Entertainment]        1
# Name: Distributor, Length: 69, dtype: int64
#
# Lionsgate Premiere                                                                                                                                                                                                                                                                                                                               2
# [Entertainment Studios Motion Pictures, Entertainment Studios Networks]                                                                                                                                                                                                                                                                          1
# [Warner Bros. Pictures Group, Warner Bros. Home Entertainment Group, Warner Bros. Television Group, Warner Bros. Global Brands & Experiences, Warner Bros. Global Kids & Young Adults, Warner Bros. Digital Networks, Warner Bros. Technology, Warner Bros. Consumer Products, Warner Bros. Theatre Ventures, Warner Bros. Studio Facilities]    1
# Name: Divisions, dtype: int64
#
# 23:00    1
# Name: Duration, dtype: int64
#
# Michael Kahn                                   26
# Maysie Hoy                                     22
# Andrew Mondshein                               21
# Stephen Mirrione                               21
# Bruce Green                                    20
#                                                ..
# [Douglas Crise, Stephen Mirrione]               1
# Connor O'Malley                                 1
# Louis Cioffi                                    1
# [Garth Craven, Samuel Craven, Dan Lebental]     1
# Osamu Inoue                                     1
# Name: Edited by, Length: 3124, dtype: int64
#
# Michael Brown                                                                                     4
# Zach Staenberg                                                                                    3
# Benjamin A. Weissman                                                                              2
# [Alan C. Marks, David Strohmaier]                                                                 2
# Sabrina Plisco                                                                                    2
#                                                                                                  ..
# David Ray                                                                                         1
# Mallory Gottlieb                                                                                  1
# Henk van Eeghen                                                                                   1
# Rick Shaine                                                                                       1
# [Lillian Benson, Betty Ciccarelli, Daniel Eisenberg, Jeanne Jordan, Thomas Ott, Charles Scott]    1
# Name: Editor(s), Length: 132, dtype: int64
#
# Various    1
# Name: Ending theme, dtype: int64
#
# Essence Engine    1
# Name: Engine, dtype: int64
#
# Quake    1
# Name: Engine(s), dtype: int64
#
# [Roger Corman, Lance H. Robbins]                         2
# [David L. Wolper, Bernard Sofronski]                     2
# [Anthea Sylbert, Paula Weinstein]                        1
# [Konstantin Thoeren, Fred Sidewater, Wolf Bauer]         1
# [Laura Bickford, Matthew Chapman, David R. Ginsburg]     1
#                                                         ..
# [Tony Danza, Diana Kerew]                                1
# [Michael Fuchs, Nicholas Paleologos, Frederick Zollo]    1
# [Michael Brandman, Tom Selleck]                          1
# [Robert Benedetti, Laurence Fishburne]                   1
# [Gerald W. Abrams, Harry B. Chandler]                    1
# Name: Executive producer(s), Length: 99, dtype: int64
#
# [Linda Magoo (mother), Granny Magoo (grandmother), Tycoon Magoo (uncle), Waldo (nephew)]    1
# Name: Family, dtype: int64
#
# Dormant    1
# Name: Fate, dtype: int64
#
# [The Purge, (2013), The Purge: Anarchy, (2014), The Purge: Election Year, (2016), The First Purge, (2018), The Purge 5, (2020)]    1
# Films                                                                                                                              1
# Name: Film(s), dtype: int64
#
# [The Ghostway, (1984)]                    1
# Around the Moon                           1
# Midnight Run for Your Life                1
# The Rainbow Trail                         1
# Sabrina Goes to Rome                      1
# Escape to Witch Mountain                  1
# Freaky Friday                             1
# The Boy Who Followed Ripley               1
# See below                                 1
# The Secret Pilgrim                        1
# Midnight Runaround                        1
# Sometimes They Come Back... Again         1
# Revenge of the Nerds IV: Nerds in Love    1
# Dallas: War of the Ewings                 1
# Name: Followed by, dtype: int64
#
# [Quake, demo recording]    1
# Name: Format(s), dtype: int64
#
# Cinépix Film Properties (1962-1998)    2
# CF Entertainment                       1
# Warner Bros. Pictures, Inc.            1
# Name: Formerly, dtype: int64
#
# [1962, ; 57 years ago, (, 1962, )]                                                           2
# [February 15, 1984, ; 35 years ago, (, 1984-02-15, )]                                        1
# 2002                                                                                         1
# [April 4, 1923, ; 96 years ago, (, 1923-04-04, ), [1]]                                       1
# [Los Angeles, ,, California, ,, United States, (1993, ; 26 years ago, (, 1993, ), ), [1]]    1
# Name: Founded, dtype: int64
#
# [Dave Christiano, Rich Christiano]    1
# Byron Allen                           1
# Ron W. Miller                         1
# Name: Founder, dtype: int64
#
# [John Dunning, Andre Link, Frank Giustra]                    2
# [Harry Warner, Albert Warner, Sam Warner, Jack L. Warner]    1
# Name: Founders, dtype: int64
#
# Le Cinquième Élément    1
# Name: French, dtype: int64
#
# Michael Edwards    1
# Name: Full name, dtype: int64
#
# Male    1
# Name: Gender, dtype: int64
#
# Drama                                20
# [Biography, Drama]                    4
# Thriller                              3
# Sci-fi                                3
# [Action, Comedy]                      3
#                                      ..
# Drama, Romance                        1
# [Adventure, Family, Fantasy]          1
# Spy novel                             1
# [Comedy, Family, Science Fiction]     1
# [Action, Adventure, Comedy]           1
# Name: Genre, Length: 87, dtype: int64
#
# Real-time strategy    1
# Action                1
# Name: Genre(s), dtype: int64
#
# [Traditional pop, easy listening, jazz, swing, vocal jazz]    1
# Name: Genres, dtype: int64
#
# Tian'anmen    1
# Name: Gwoyeu Romatzyh, dtype: int64
#
# 원더풀 데이즈    1
# 파이 스토리     1
# Name: Hangul, dtype: int64
#
# Tiān'ānmén    1
# Name: Hanyu Pinyin, dtype: int64
#
# [Santa Monica, California, ,, U.S.]                             2
# [Burbank, ,, California, ,, United States]                      1
# United States                                                   1
# [4000 Warner Blvd,, Burbank, California, ,, United States]      1
# [Century City, ,, Los Angeles, California, ,, United States]    1
# Name: Headquarters, dtype: int64
#
# פוֹקְסטְרוֹט    1
# Name: Hebrew, dtype: int64
#
# 5 ft 11 in (180 cm)    1
# 1.73 m (5 ft 8 in)     1
# Name: Height, dtype: int64
#
# Omoide no Mānī                                     1
# Meari to Majo no Hana                              1
# Boku no Hīrō Akademia THE MOVIE: Futari no Hīrō    1
# Manbiki Kazoku                                     1
# Name: Hepburn, dtype: int64
#
# Thian-an-mn̂g    1
# Name: Hokkien POJ, dtype: int64
#
# [tʰíːn.ɔ́ːn.mȕːn]    1
# Name: IPA, dtype: int64
#
# [.mw-parser-output cite.citation{font-style:inherit}.mw-parser-output .citation q{quotes:"\"""\"""'""'"}.mw-parser-output .citation .cs1-lock-free a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Lock-green.svg/9px-Lock-green.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .citation .cs1-lock-limited a,.mw-parser-output .citation .cs1-lock-registration a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Lock-gray-alt-2.svg/9px-Lock-gray-alt-2.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .citation .cs1-lock-subscription a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Lock-red-alt-2.svg/9px-Lock-red-alt-2.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration{color:#555}.mw-parser-output .cs1-subscription span,.mw-parser-output .cs1-registration span{border-bottom:1px dotted;cursor:help}.mw-parser-output .cs1-ws-icon a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/12px-Wikisource-logo.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output code.cs1-code{color:inherit;background:inherit;border:inherit;padding:inherit}.mw-parser-output .cs1-hidden-error{display:none;font-size:100%}.mw-parser-output .cs1-visible-error{font-size:100%}.mw-parser-output .cs1-maint{display:none;color:#33aa33;margin-left:0.3em}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration,.mw-parser-output .cs1-format{font-size:95%}.mw-parser-output .cs1-kern-left,.mw-parser-output .cs1-kern-wl-left{padding-left:0.2em}.mw-parser-output .cs1-kern-right,.mw-parser-output .cs1-kern-wl-right{padding-right:0.2em}, 0-340-50573-7, (hardback edition)]    1
# [.mw-parser-output cite.citation{font-style:inherit}.mw-parser-output .citation q{quotes:"\"""\"""'""'"}.mw-parser-output .citation .cs1-lock-free a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Lock-green.svg/9px-Lock-green.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .citation .cs1-lock-limited a,.mw-parser-output .citation .cs1-lock-registration a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Lock-gray-alt-2.svg/9px-Lock-gray-alt-2.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .citation .cs1-lock-subscription a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Lock-red-alt-2.svg/9px-Lock-red-alt-2.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration{color:#555}.mw-parser-output .cs1-subscription span,.mw-parser-output .cs1-registration span{border-bottom:1px dotted;cursor:help}.mw-parser-output .cs1-ws-icon a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/12px-Wikisource-logo.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output code.cs1-code{color:inherit;background:inherit;border:inherit;padding:inherit}.mw-parser-output .cs1-hidden-error{display:none;font-size:100%}.mw-parser-output .cs1-visible-error{font-size:100%}.mw-parser-output .cs1-maint{display:none;color:#33aa33;margin-left:0.3em}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration,.mw-parser-output .cs1-format{font-size:95%}.mw-parser-output .cs1-kern-left,.mw-parser-output .cs1-kern-wl-left{padding-left:0.2em}.mw-parser-output .cs1-kern-right,.mw-parser-output .cs1-kern-wl-right{padding-right:0.2em}, 0-434-33514-2]                        1
# [.mw-parser-output cite.citation{font-style:inherit}.mw-parser-output .citation q{quotes:"\"""\"""'""'"}.mw-parser-output .citation .cs1-lock-free a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Lock-green.svg/9px-Lock-green.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .citation .cs1-lock-limited a,.mw-parser-output .citation .cs1-lock-registration a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Lock-gray-alt-2.svg/9px-Lock-gray-alt-2.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .citation .cs1-lock-subscription a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Lock-red-alt-2.svg/9px-Lock-red-alt-2.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration{color:#555}.mw-parser-output .cs1-subscription span,.mw-parser-output .cs1-registration span{border-bottom:1px dotted;cursor:help}.mw-parser-output .cs1-ws-icon a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/12px-Wikisource-logo.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output code.cs1-code{color:inherit;background:inherit;border:inherit;padding:inherit}.mw-parser-output .cs1-hidden-error{display:none;font-size:100%}.mw-parser-output .cs1-visible-error{font-size:100%}.mw-parser-output .cs1-maint{display:none;color:#33aa33;margin-left:0.3em}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration,.mw-parser-output .cs1-format{font-size:95%}.mw-parser-output .cs1-kern-left,.mw-parser-output .cs1-kern-wl-left{padding-left:0.2em}.mw-parser-output .cs1-kern-right,.mw-parser-output .cs1-kern-wl-right{padding-right:0.2em}, 0-15-662870-8]                        1
# [.mw-parser-output cite.citation{font-style:inherit}.mw-parser-output .citation q{quotes:"\"""\"""'""'"}.mw-parser-output .citation .cs1-lock-free a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Lock-green.svg/9px-Lock-green.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .citation .cs1-lock-limited a,.mw-parser-output .citation .cs1-lock-registration a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Lock-gray-alt-2.svg/9px-Lock-gray-alt-2.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .citation .cs1-lock-subscription a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Lock-red-alt-2.svg/9px-Lock-red-alt-2.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration{color:#555}.mw-parser-output .cs1-subscription span,.mw-parser-output .cs1-registration span{border-bottom:1px dotted;cursor:help}.mw-parser-output .cs1-ws-icon a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/12px-Wikisource-logo.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output code.cs1-code{color:inherit;background:inherit;border:inherit;padding:inherit}.mw-parser-output .cs1-hidden-error{display:none;font-size:100%}.mw-parser-output .cs1-visible-error{font-size:100%}.mw-parser-output .cs1-maint{display:none;color:#33aa33;margin-left:0.3em}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration,.mw-parser-output .cs1-format{font-size:95%}.mw-parser-output .cs1-kern-left,.mw-parser-output .cs1-kern-wl-left{padding-left:0.2em}.mw-parser-output .cs1-kern-right,.mw-parser-output .cs1-kern-wl-right{padding-right:0.2em}, 0-679-42922-0]                        1
# [.mw-parser-output cite.citation{font-style:inherit}.mw-parser-output .citation q{quotes:"\"""\"""'""'"}.mw-parser-output .citation .cs1-lock-free a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/6/65/Lock-green.svg/9px-Lock-green.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .citation .cs1-lock-limited a,.mw-parser-output .citation .cs1-lock-registration a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/d/d6/Lock-gray-alt-2.svg/9px-Lock-gray-alt-2.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .citation .cs1-lock-subscription a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Lock-red-alt-2.svg/9px-Lock-red-alt-2.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration{color:#555}.mw-parser-output .cs1-subscription span,.mw-parser-output .cs1-registration span{border-bottom:1px dotted;cursor:help}.mw-parser-output .cs1-ws-icon a{background:url("//upload.wikimedia.org/wikipedia/commons/thumb/4/4c/Wikisource-logo.svg/12px-Wikisource-logo.svg.png")no-repeat;background-position:right .1em center}.mw-parser-output code.cs1-code{color:inherit;background:inherit;border:inherit;padding:inherit}.mw-parser-output .cs1-hidden-error{display:none;font-size:100%}.mw-parser-output .cs1-visible-error{font-size:100%}.mw-parser-output .cs1-maint{display:none;color:#33aa33;margin-left:0.3em}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration,.mw-parser-output .cs1-format{font-size:95%}.mw-parser-output .cs1-kern-left,.mw-parser-output .cs1-kern-wl-left{padding-left:0.2em}.mw-parser-output .cs1-kern-right,.mw-parser-output .cs1-kern-wl-right{padding-right:0.2em}, 0-06-014936-1]                        1
# Name: ISBN, dtype: int64
#
# [Alphonse de Neuville, and, Édouard Riou]    1
# John Tenniel                                 1
# Douglas Duer                                 1
# Name: Illustrator, dtype: int64
#
# Motion pictures                                             3
# [Television production, Broadcasting, Film distribution]    1
# Entertainment                                               1
# Name: Industry, dtype: int64
#
# Vocals    1
# Name: Instruments, dtype: int64
#
# [僕のヒーローアカデミア THE MOVIE ～２人の, .mw-parser-output ruby>rt,.mw-parser-output ruby>rtc{font-feature-settings:"ruby"1}.mw-parser-output ruby.large{font-size:250%}.mw-parser-output ruby.large>rt,.mw-parser-output ruby.large>rtc{font-size:.3em}, 英雄, （, ヒーロー, ）, ～]    1
# 思い出のマーニー                                                                                                                                                                                                                                                            1
# 万引き家族                                                                                                                                                                                                                                                               1
# メアリと魔女の花                                                                                                                                                                                                                                                            1
# Name: Japanese, dtype: int64
#
# Tin1on1mun4    1
# Name: Jyutping, dtype: int64
#
# [Joe Drake, (film group chairman), Patrick Wachsberger, Rob Friedman, (, Co-Chairmen, )]    2
# [Byron Allen (, chairman, ,, CEO, ), [1]]                                                   1
# [Ann Sarnoff, (Chair and CEO)]                                                              1
# Name: Key people, dtype: int64
#
# PR3404.M6                     1
# PR6062.E33 R87 1989b          1
# PR6045.O72 M7 1990b           1
# PZ3.H53985 Rk5 PS3558.I366    1
# F294.S2 B48 1994              1
# Name: LC Class, dtype: int64
#
# [Warner Music Vision, Warner-Reprise Video, Maverick, Sire, Warner Bros.]    1
# Columbia                                                                     1
# Epitaph                                                                      1
# Slave Pit, Inc.                                                              1
# Name: Label, dtype: int64
#
# [RCA Victor, Columbia, Capitol, Reprise, Warner Bros.]    1
# Name: Labels, dtype: int64
#
# English                                6361
# [English, Spanish]                       77
# [English, French]                        35
# [English, Japanese]                      28
# [English, Russian]                       23
#                                        ...
# English, Vietnamese, Japanese             1
# [Korean, English]                         1
# English/Spanish                           1
# [Syriac, Aramaic, English, Italian]       1
# [Mandarin, English, Korean]               1
# Name: Language, Length: 224, dtype: int64
#
# [25, :, 03]    1
# 90 min         1
# 117 mins       1
# Name: Length, dtype: int64
#
# "Gate of Heavenly Peace"    1
# Name: Literal meaning, dtype: int64
#
# Case No. 23                1
# Marnie of [my] Memories    1
# Shoplifting Family         1
# Name: Literally, dtype: int64
#
# Dōng Gōng Xī Gōng    1
# Yè Wèn Sān           1
# Xǐyàn                1
# Cháng Chéng          1
# Name: Mandarin, dtype: int64
#
# P‘ai sŭt‘ori       1
# Wŏndŏp‘ul teijŭ    1
# Name: McCune–Reischauer, dtype: int64
#
# Print (hardback and paperback)          3
# [Print:, octavo]                        1
# Print (hardback & paperback)            1
# Print                                   1
# Print and audio                         1
# Paper, 8vo                              1
# [Print (, Hardback, &, Paperback, )]    1
# Name: Media type, dtype: int64
#
# [Single-player, ,, multiplayer]    1
# Name: Mode(s), dtype: int64
#
# True Colors    1
# Name: Music, dtype: int64
# James Newton Howard                                                      98
# Mark Isham                                                               89
# John Debney                                                              82
# Christophe Beck                                                          72
# Hans Zimmer                                                              70
#                                                                          ..
# [Peter Stuart, Andrew Williams]                                           1
# Kerry Muzzey                                                              1
# [Songs, :, Lin-Manuel Miranda, Opetaia Foa'i, Score, :, Mark Mancina]     1
# [Chris Jagich, Ryan Greene]                                               1
# Toydrum                                                                   1
# Name: Music by, Length: 2315, dtype: int64
#
# Chérie, j'ai rétréci le public    1
# Name: Name, dtype: int64
#
# Roscoe Lee Browne                                                                             5
# John Hurt                                                                                     4
# John Ingle                                                                                    4
# Tom Kane                                                                                      4
# Michael Moore                                                                                 4
#                                                                                              ..
# Charles Osgood                                                                                1
# Woody Strode                                                                                  1
# James Corden                                                                                  1
# Junior Brown                                                                                  1
# [W.K. Border, Thomas Calabrese, Takashige Ichise, Aki Komine, Michael Leahy, Joel Soisson]    1
# Name: Narrated by, Length: 242, dtype: int64
#
# American     2
# Australia    1
# Name: Nationality, dtype: int64
#
# 1                               2
# [26, (, list of episodes, )]    1
# 4                               1
# 10                              1
# 14                              1
# Name: No. of episodes, dtype: int64
#
# 1    1
# Name: No. of seasons, dtype: int64
#
# Novels    1
# Name: Novel(s), dtype: int64
#
# [200 (2017, [1], )]    1
# Est. 8,000 (2014)      1
# Name: Number of employees, dtype: int64
#
# 7738198      1
# 702355312    1
# 27975809     1
# 1057535      1
# 20932825     1
# 19271245     1
# Name: OCLC, dtype: int64
#
# [Singer, actor, producer]                     1
# Film director, screenwriter                   1
# Actor                                         1
# Actor, director                               1
# Film producer, screenwriter, film director    1
# Horse trainer, author                         1
# [Film director, ,, screenwriter]              1
# [Actor, model, producer, director]            1
# Name: Occupation, dtype: int64
#
# March 28, 1999    1
# Name: Opening date, dtype: int64
#
# [", Keep Your Eyes on the Prize, "]        1
# "Ducks Rock" performed by Mickey Thomas    1
# Name: Opening theme, dtype: int64
#
# US$1.761 billion (2017)    1
# Name: Operating income, dtype: int64
#
# English    2
# Name: Original language, dtype: int64
#
# English              161
# [English, German]      1
# English language       1
# English, German        1
# Name: Original language(s), dtype: int64
#
# ABC                                               22
# CBS                                               21
# NBC                                               19
# HBO                                               15
# Showtime                                          15
# Fox                                                8
# TNT                                                7
# Disney Channel                                     4
# USA Network                                        2
# MTV                                                1
# Syndicated                                         1
# [ABC, NBC, Fox, CBS, USA Network, Syndication]     1
# American Broadcasting Company                      1
# Super RTL                                          1
# PBS                                                1
# [A&E, (US)]                                        1
# ITV (TV network)                                   1
# USA                                                1
# Lifetime                                           1
# FX                                                 1
# Syndication                                        1
# TBS                                                1
# Canadian Broadcasting Corporation                  1
# MGM Television                                     1
# The Family Channel                                 1
# ITV                                                1
# [ABC, Syndication]                                 1
# Name: Original network, dtype: int64
#
# [February 13, 1994, (, 1994-02-13, )]                                               2
# [April 21, 1990, (, 1990-04-21, ), (USA), June 22, 1990, (, 1990-06-22, ), (UK)]    1
# May 18, 2002                                                                        1
# [August 13, 1995, (, 1995-08-13, )]                                                 1
# [November 5, 1995, (, 1995-11-05, )]                                                1
#                                                                                    ..
# [August 23, 1997, (, 1997-08-23TUnited States, )]                                   1
# [September 6, 1996, (, 1996-09-06, ), –, January 17, 1997, (, 1997-01-17, )]        1
# [January 19, 1997, (, 1997-01-19, )]                                                1
# [9 March 1997, (, 1997-03-09, ), (UK), 19 October 1997, (, 1997-10-19, ), (US)]     1
# [February 25, 1990, (, 1990-02-25, )]                                               1
# Name: Original release, Length: 164, dtype: int64
#
# ואלס עם באשיר                       1
# Vingt mille lieues sous les mers    1
# Name: Original title, dtype: int64
#
# [The Purge, (2013)]    1
# Name: Original work, dtype: int64
#
# Scott Reeves    1
# Name: Other names, dtype: int64
#
# Lionsgate             2
# AT&T                  1
# Byron Allen (100%)    1
# Name: Owner, dtype: int64
#
# [Houghton: 520, Macmillan: volume one, 266; volume two, 253; volume three, 248]    1
# 214                                                                                1
# 335                                                                                1
# 389 pp                                                                             1
# 384 pp (hardback edition)                                                          1
# 288 pp                                                                             1
# xiii,424                                                                           1
# Name: Pages, dtype: int64
#
# The Walt Disney Studios    1
# WarnerMedia                1
# Name: Parent, dtype: int64
#
# [Antonino Martino Sinatra, Natalina Garaventa]    1
# [Clint Eastwood, Jacelyn Reeves]                  1
# Name: Parent(s), dtype: int64
#
# Color                                        62
# Color (Technicolor)                           2
# [Color, Black and White (some sequences)]     1
# Black-and-white                               1
# 4:3                                           1
# Color (Deluxe)                                1
# [SD, :, 4:3]                                  1
# Name: Picture format, dtype: int64
#
# [Old Globe Theatre, (, San Diego, , California)]    1
# [The Flea Theater, New York City]                   1
# [Royal Dramatic Theatre, Stockholm, , Sweden]       1
# Name: Place premiered, dtype: int64
#
# [Microsoft Windows, ,, OS X, [1]]    1
# Name: Platform(s), dtype: int64
#
# Zimna wojna    1
# Name: Polish, dtype: int64
#
# [Jim Backus, (1949–1989), Leslie Nielsen, (film), Greg Burson, (film, animated segments), Jim Conroy, (, Kung Fu Magoo, ), Ian Hanlin, (TV)]    1
# Name: Portrayed by, dtype: int64
#
# [People of Darkness, (1980)]                     1
# The Shaggy Dog                                   1
# Revenge of the Nerds II: Nerds in Paradise       1
# The Heritage of the West                         1
# In Search of the Castaways                       1
# The Computer Wore Tennis Shoes                   1
# Alice's Adventures in Wonderland                 1
# Psycho III                                       1
# The Birds                                        1
# Ripley Under Ground                              1
# Midnight Runaround                               1
# Problem Child 2                                  1
# Revenge of the Nerds III: The Next Generation    1
# Dallas                                           1
# [Blind Faith, (1990)]                            1
# A Perfect Spy                                    1
# Name: Preceded by, dtype: int64
#
# [Trimark Pictures, Artisan Entertainment]    2
# Warner Features Company                      1
# Name: Predecessor, dtype: int64
# Jerry Bruckheimer                                                                                 18
# Robert Simonds                                                                                    18
# Brian Grazer                                                                                      17
# Kevin Feige                                                                                       15
# John Davis                                                                                        14
#                                                                                                   ..
# [Neal H. Moritz, David Dobkin, Bryan Singer, Patrick McCormick, Ori Marmur]                        1
# [Mike White, Ben Le Clair, Dede Gardner]                                                           1
# [Jason Blum, Amy Israel, Uma Thurman]                                                              1
# [Letty Aronson, Richard Brick, J.E. Beaucaire, Jean Doumanian, Charles H. Joffe, Jack Rollins]     1
# [Michael Shamberg, Stacey Sher, Carla Santos]                                                      1
# Name: Produced by, Length: 5878, dtype: int64
#
# [Pennywise, ,, Darren Doan]                    1
# Marty Callner                                  1
# [Toby "Flobee" Wright, and Alice in Chains]    1
# Name: Producer, dtype: int64
#
# Joseph B. Wallenstein                                                                   2
# Mike Elliott                                                                            2
# [Tony To, Ellen Erwin]                                                                  2
# David Coatsworth                                                                        2
# [Ian Martin, John Perrin Flynn (co-producer), Benjamin A. Weissman (co-producer)]       1
#                                                                                        ..
# Robert Greenhut                                                                         1
# [John Frankenheimer, Julian Krainin]                                                    1
# Don Carmody                                                                             1
# [Riley Kathryn Ellis, Monte Merrick, Christopher Seitz]                                 1
# [Gary M. Goodman, Barry Rosen, John Byers (co-producer), Stephen Alix (co-producer)]    1
# Name: Producer(s), Length: 157, dtype: int64
#
# United Ranger Films    1
# Name: Production company, dtype: int64
#
# Walt Disney Television                                                 5
# HBO Pictures                                                           3
# HBO Showcase                                                           2
# Warner Bros. Television                                                2
# Signboard Hill Productions                                             2
#                                                                       ..
# [Hallmark, American Zoetrope]                                          1
# [Dan Wigutow Productions, Paramount Network Television Productions]    1
# B-Reel Films                                                           1
# [The Polone-Winer Company, NBC Studios]                                1
# [Southern Star Productions, Wang Film Productions, (animation)]        1
# Name: Production company(s), Length: 125, dtype: int64
#
# Los Angeles                                                                                                                                                                                                                                           6
# Vancouver                                                                                                                                                                                                                                             3
# Toronto                                                                                                                                                                                                                                               2
# [Paramount Ranch - 2813 Cornell Road,, Agoura, California]                                                                                                                                                                                            1
# [Southport, North Carolina, Wilmington, North Carolina]                                                                                                                                                                                               1
# [Budapest, Hungary, St. Petersburg, Russia]                                                                                                                                                                                                           1
# [4th Street Viaduct, Los Angeles, California, Santa Fe Avenue, Downtown, Los Angeles]                                                                                                                                                                 1
# [Independence, Missouri, Kansas City, Missouri, Leavenworth, Kansas, Lee's Summit, Missouri, Topeka, Kansas, Weston, Missouri]                                                                                                                        1
# [1090 Rubio Street,, Altadena, California]                                                                                                                                                                                                            1
# [Garden of the Gods, Colorado Springs, Colorado, Ogden, Utah, Pleasant Grove, Utah, Midvale, Utah, Salt Lake City, Tooele, Utah, Lehi, Utah, Magna, Utah, Cedar Fort, Utah, Pittsburgh, Pennsylvania, New York City, Fremont Street, ,, Las Vegas]    1
# [Los Angeles, Venice, California]                                                                                                                                                                                                                     1
# [Chateau Bradbury Estate, Malibu, California]                                                                                                                                                                                                         1
# [2nd Street Tunnel between Hill and Figueroa, Los Angeles, California, Los Angeles City Hall, Sperry, Oklahoma]                                                                                                                                       1
# ...
# Name: Series, dtype: int64
#
# Film distribution    2
# Name: Services, dtype: int64
#
# [Navajo Nation, and, Hopi Reservation, in Southwestern United States]    1
# [England, and, Virginia Colony, , 1613–1683]                             1
# Name: Set in, dtype: int64
#
# New York in the 1980s                          1
# The summer home of the Tyrones, August 1912    1
# Name: Setting, dtype: int64
#
# 长城         1
# 东宫西宫       1
# 叶问3        1
# 我们诞生在中国    1
# Name: Simplified, dtype: int64
#
# 天安门    1
# Name: Simplified Chinese, dtype: int64
#
# Human    1
# Name: Species, dtype: int64
#
# [Nancy Barbato, (, m., 1939, ;, div., 1951, ), Ava Gardner, (, m., 1951;, div., 1957), Mia Farrow, (, m., 1966, ;, div., 1968), Barbara Marx, (, m., 1976, )]    1
# Name: Spouse(s), dtype: int64
# see below                                                                                                                                                          6
# [Gary Graham, Eric Pierpoint, Michele Scarabelli, Terri Treas]                                                                                                     4
# See below                                                                                                                                                          4
# [Ethan Hawke, Julie Delpy]                                                                                                                                         3
# [Matthew Barney, Aimee Mullins, Richard Serra, Norman Mailer, Ursula Andress]                                                                                      3
#                                                                                                                                                                   ..
# [Lukas Haas, David Arquette, Keith David, Christopher Gartin, Elliott Gould, Terrence Dashon Howard, Nicky Katt, Richard Kind, John C. McGinley, Arliss Howard]    1
# [John Lloyd Young, Erich Bergen, Michael Lomenda, Vincent Piazza, Christopher Walken]                                                                              1
# [James Arnold Taylor, David Kaye, Paul Giamatti, John Goodman, Bella Thorne, Rosario Dawson, Jim Ward, Sylvester Stallone]                                         1
# [Nia Vardalos, John Corbett]                                                                                                                                       1
# [Sean Penn, Jude Law, Kate Winslet, James Gandolfini, Mark Ruffalo, Patricia Clarkson, Jackie Earle Haley, Anthony Hopkins]                                        1
# Name: Starring, Length: 6856, dtype: int64
#
# Closed    1
# Name: Status, dtype: int64
#
# Luc Besson                          4
# Frank Miller                        3
# [Brian Nissen, Richard Rich]        3
# Andrew Stanton                      3
# George Lucas                        3
#                                    ..
# John Logan                          1
# [Barbara Turner, Neve Campbell]     1
# [Michael Berry, John Blumenthal]    1
# Hampton Fancher                     1
# Paul Monash                         1
# Name: Story by, Length: 959, dtype: int64
#
# An autobiographical account of his explosive home life with a drug-addicted mother.    1
# Horse training                                                                         1
# Name: Subject, dtype: int64
#
# [Globalgate Entertainment, [1], Grindstone Entertainment Group, Pantelion Films, (50%), Roadside Attractions, (45%), Summit Entertainment, Good Universe]                                                                                                                                                                                                                                                                                                                              2
# [Allen Media Broadcasting, Freestyle Releasing, The Grio, The Weather Channel]                                                                                                                                                                                                                                                                                                                                                                                                         1
# [Warner Bros. Pictures, New Line Cinema, DC Films, Warner Home Video, Warner Bros. Interactive Entertainment, Warner Bros. Television, DC Entertainment, DC Comics, Warner Bros. Animation, Warner Animation Group, Cartoon Network, Cartoon Network Studios, Adult Swim, Williams Street, Turner Entertainment, [4], Castle Rock Entertainment, WaterTower Music, The CW, (50%), Flagship Entertainment, (49%), Fandango Media, (30%), Spyglass Media Group, (minority), Studio T]    1
# Name: Subsidiaries, dtype: int64
#
# [Character from, Profumo di donna, by, Ruggero Maccari, Dino Risi]    1
# Name: Suggested by, dtype: int64
#
# [The Purge, (2018–present)]    1
# Name: Television series, dtype: int64
#
# [The Fortunes and Misfortunes of the Famous Moll Flanders, at, Wikisource]    1
# [The Woodlanders, at, Wikisource]                                             1
# Name: Text, dtype: int64
#
# Mark Snow                                                                                             3
# Gary Chang                                                                                            3
# Hummie Mann                                                                                           2
# Peter Rodgers Melnick                                                                                 2
# Steve Dorff                                                                                           2
# George S. Clinton                                                                                     2
# Lee Holdridge                                                                                         2
# David Kurtz                                                                                           2
# Richard Harvey                                                                                        2
# David Michael Frank                                                                                   2
# James Newton Howard                                                                                   2
# W.G. Snuffy Walden                                                                                    1
# Phil Marshall                                                                                         1
# Cliff Eidelman                                                                                        1
# Louis Natale                                                                                          1
# Patrick Williams                                                                                      1
# Dana Kaproff                                                                                          1
# Peter Manning Robinson                                                                                1
# [Richard Kosinski, Sam Winans, Paul Buckmaster, Bill Reichenbach, Bob Mann, Guy Moon, Alan Menken]    1
# Richard Stone                                                                                         1
# Trevor Lawrence                                                                                       1
# Christopher L. Stone                                                                                  1
# John Ottman                                                                                           1
# Carl Swander Johnson                                                                                  1
# Laurence Rosenthal                                                                                    1
# [Danny Troob, Songs:, Charles Strouse (music), Martin Charnin (lyrics)]                               1
# [Jeff Eden Fair, Starr Parodi]                                                                        1
# Richard Bellis                                                                                        1
# [Cliff Eidelman, Nicholas Pike]                                                                       1
# [Paul Boll, Johnny Reno]                                                                              1
# Terry Plumeri                                                                                         1
# Ira Newborn                                                                                           1
# Jerrold Immel                                                                                         1
# Van Dyke Parks                                                                                        1
# David Reynolds                                                                                        1
# Johnny Harris                                                                                         1
# Brad Fiedel                                                                                           1
# John Scott                                                                                            1
# Gary S. Scott                                                                                         1
# J. Steven Soles                                                                                       1
# David Mansfield                                                                                       1
# Larry Blank                                                                                           1
# Bruce Broughton                                                                                       1
# Nan Schwartz                                                                                          1
# Jay Gruska                                                                                            1
# Michael Richard Plowman                                                                               1
# Maurice Jarre                                                                                         1
# J.A.C. Redford                                                                                        1
# Gerald Gouriet                                                                                        1
# Parmer Fuller                                                                                         1
# John Kander                                                                                           1
# Don Davis                                                                                             1
# Marty Simon                                                                                           1
# Shirley Walker                                                                                        1
# Paul Zaza                                                                                             1
# Brian Keane                                                                                           1
# Michael Cruz                                                                                          1
# Name: Theme music composer, dtype: int64
#
# [$1 billion (2017, [1], )]    1
# Name: Total assets, dtype: int64
#
# 長城         1
# 葉問3        1
# 東宮西宮       1
# 我們誕生在中國    1
# 喜宴         1
# Name: Traditional, dtype: int64
#
# 天安門    1
# Name: Traditional Chinese, dtype: int64
#
# [Transcriptions, Standard Mandarin, Hanyu Pinyin, Tiān'ānmén, Bopomofo, ㄊㄧㄢ   ㄢ   ㄇㄣˊ, Gwoyeu Romatzyh, Tian'anmen, Wade–Giles, Tʻien, 1, -an, 1, -mên, 2, IPA, [tʰjɛ́n.án.mə̌n], Yue: Cantonese, Yale Romanization, Tīn'ōnmùhn, IPA, [tʰíːn.ɔ́ːn.mȕːn], Jyutping, Tin1on1mun4, Southern Min, Hokkien, POJ, Thian-an-mn̂g]    1
# Name: Transcriptions, dtype: int64
#
# Division               3
# Private corporation    1
# Filmmaking             1
# Label                  1
# Name: Type, dtype: int64
#
# [Sydney Cricket Ground, (, Sydney, Australia, )]    1
# Name: Venue, dtype: int64
#
# [Don Messick, Casey Kasem, Eddie Deezen, Greg Burson, Allan Melvin, Charlie Adler, Brian Cummings, Rob Paulsen, Frank Welker, Kath Soucie, Jennifer Hale, Maurice LaMarche, John Kassir]    1
# See full below                                                                                                                                                                              1
# [Ian Ziering, James Belushi, Jeff Bennett, Clancy Brown, Tim Curry, Dennis Franz, Brad Garrett, Jennifer Hale, Tony Jay, Steve Mackall, Frank Welker, April Winchell]                       1
# Name: Voices of, dtype: int64
#
# [Tʻien, 1, -an, 1, -mên, 2]    1
# Name: Wade–Giles, dtype: int64
#
# [www, .lionsgate, .com, /movies, /]    2
# [sinatra, .com]                        1
# Official website                       1
# [www, .warnerbros, .com]               1
# [entertainmentstudios, .com]           1
# [www, .touchstonepictures, .com]       1
# Name: Website, dtype: int64
#
# [Duane Pye, Paris Qualles]    1
# Name: Writer(s), dtype: int64
# Woody Allen                                              24
# Tyler Perry                                              18
# Kevin Smith                                              11
# M. Night Shyamalan                                       10
# John Hughes                                               9
#                                                          ..
# Bill Dear                                                 1
# Björne Larson                                             1
# [Nick Tomnay, Krishna Jones]                              1
# [Joel Coen, Ethan Coen, George Clooney, Grant Heslov]     1
# Kerry Conran                                              1
# Name: Written by, Length: 3696, dtype: int64
#
# Tīn'ōnmùhn    1
# Name: Yale Romanization, dtype: int64
#
# 1990–present    1
# 2006–present    1
# 2001–present    1
# 1935–95         1
# 1999–present    1
# 2012–present    1
# Name: Years active, dtype: int64
#
# מנשה    1
# Name: Yiddish, dtype: int64
#
# https://www.imdb.com/title/tt0321780/    3
# https://www.imdb.com/title/tt1935896/    2
# https://www.imdb.com/title/tt0290212/    2
# https://www.imdb.com/title/tt0119256/    2
# https://www.imdb.com/title/tt2023765/    2
#                                         ..
# https://www.imdb.com/title/tt0107034/    1
# https://www.imdb.com/title/tt0105411/    1
# https://www.imdb.com/title/tt0113965/    1
# https://www.imdb.com/title/tt0466839/    1
# https://www.imdb.com/title/tt2002718/    1
# Name: imdb_link, Length: 7055, dtype: int64
#
# Beauty and the Beast                      4
# Masterminds                               3
# Titanic                                   3
# The Three Musketeers                      3
# The Cremaster Cycle                       3
#                                          ..
# Pray the Devil Back to Hell               1
# Lethal Weapon 3                           1
# Pulse                                     1
# Quantum Quest: A Cassini Space Odyssey    1
# Stateside                                 1
# Name: title, Length: 7005, dtype: int64
#
# https://en.wikipedia.org/wiki/The_Cremaster_Cycle        3
# https://en.wikipedia.org/wiki/Full_Frontal_(film)        2
# https://en.wikipedia.org/wiki/The_Unspeakable_Act        2
# https://en.wikipedia.org/wiki/Shipwrecked_(1990_film)    2
# https://en.wikipedia.org/wiki/Black_Rock_(2012_film)     2
#                                                         ..
# https://en.wikipedia.org/wiki/Incredibles_2              1
# https://en.wikipedia.org/wiki/Doc_Hollywood              1
# https://en.wikipedia.org/wiki/The_Lodgers_(film)         1
# https://en.wikipedia.org/wiki/D2:_The_Mighty_Ducks       1
# https://en.wikipedia.org/wiki/Apt_Pupil_(film)           1
# Name: url, Length: 7113, dtype: int64
#
# 2006.0    406
# 2013.0    370
# 1997.0    350
# 1996.0    347
# 1995.0    299
# 2007.0    295
# 2012.0    294
# 1994.0    280
# 1990.0    265
# 2018.0    264
# 1998.0    237
# 2004.0    235
# 2017.0    235
# 2005.0    229
# 2002.0    227
# 2009.0    224
# 2003.0    220
# 2001.0    218
# 1992.0    218
# 1999.0    217
# 2014.0    210
# 2000.0    210
# 2010.0    209
# 2008.0    207
# 1991.0    201
# 2011.0    200
# 1993.0    198
# 2015.0    145
# 2016.0    143
# Name: year, dtype: int64

# %%
clean_movies = [clean_movie(movie) for movie in wiki_movies]

# %%
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Picture format',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    # combine alternate titles into one list
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune-Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles

    # merge column names
    def change_column_name(old_name, new_name):
        if old_name in movie:
            movie[new_name] = movie.pop(old_name)
    change_column_name('Adaptation by', 'Writer(s)')
    change_column_name('Country of origin', 'Country')
    change_column_name('Directed by', 'Director')
    change_column_name('Distributed by', 'Distributor')
    change_column_name('Edited by', 'Editor(s)')
    change_column_name('Length', 'Running time')
    change_column_name('Original release', 'Release date')
    change_column_name('Music by', 'Composer(s)')
    change_column_name('Produced by', 'Producer(s)')
    change_column_name('Producer', 'Producer(s)')
    change_column_name('Productioncompanies ', 'Production company(s)')
    change_column_name('Productioncompany ', 'Production company(s)')
    change_column_name('Released', 'Release Date')
    change_column_name('Release Date', 'Release date')
    change_column_name('Screen story by', 'Writer(s)')
    change_column_name('Screenplay by', 'Writer(s)')
    change_column_name('Story by', 'Writer(s)')
    change_column_name('Theme music composer', 'Composer(s)')
    change_column_name('Written by', 'Writer(s)')

    return movie

# %%
clean_movies = [clean_movie(movie) for movie in wiki_movies]
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Created by',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'McCune–Reischauer',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Picture format',
#  'Preceded by',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Recorded',
#  'Release date',
#  'Running time',
#  'Starring',
#  'Suggested by',
#  'Venue',
#  'Voices of',
#  'Writer(s)',
#  'alt_titles',
#  'imdb_link',
#  'title',
#  'url',
#  'year']

# %%
wiki_movies_df['imdb_id'] = wiki_movies_df['imdb_link'].str.extract(r'(tt\d{7})')
print(len(wiki_movies_df))
wiki_movies_df.drop_duplicates(subset='imdb_id', inplace=True)
print(len(wiki_movies_df))
wiki_movies_df.head()
# Out:
# 7076
# 7033
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#                                             Based on  \
# 0                        [Characters, by Rex Weiner]
# 1  [the novel, After Dark, My Sweet, by, Jim Thom...
# 2             [Air America, by, Christopher Robbins]
# 3                                                NaN
# 4                                                NaN
#
#                                             Starring         Narrated by  \
# 0  [Andrew Dice Clay, Wayne Newton, Priscilla Pre...  Andrew "Dice" Clay
# 1  [Jason Patric, Rachel Ward, Bruce Dern, George...                 NaN
# 2  [Mel Gibson, Robert Downey Jr., Nancy Travis, ...                 NaN
# 3  [Alec Baldwin, Blythe Danner, Judy Davis, Mia ...                 NaN
# 4        [Paul Hogan, Elias Koteas, Linda Kozlowski]                 NaN
#
#    Cinematography                                       Release date  \
# 0     Oliver Wood                  [July 11, 1990, (, 1990-07-11, )]
# 1    Mark Plummer  [May 17, 1990, (, 1990-05-17, ), (Cannes Film ...
# 2   Roger Deakins                [August 10, 1990, (, 1990-08-10, )]
# 3  Carlo Di Palma              [December 25, 1990, (, 1990-12-25, )]
# 4    Russell Boyd                                  December 19, 1990
#
#   Running time  ... Preceded by Suggested by alt_titles Recorded Venue Label  \
# 0  102 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
# 1  114 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
# 2  113 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
# 3  106 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
# 4   95 minutes  ...         NaN          NaN        NaN      NaN   NaN   NaN
#
#   Animation by Color process McCune–Reischauer    imdb_id
# 0          NaN           NaN               NaN  tt0098987
# 1          NaN           NaN               NaN  tt0098994
# 2          NaN           NaN               NaN  tt0099005
# 3          NaN           NaN               NaN  tt0099012
# 4          NaN           NaN               NaN  tt0099018
#
# [5 rows x 41 columns]

# %%
[[column,wiki_movies_df[column].isnull().sum()] for column in wiki_movies_df.columns]
# Out:
# [['url', 0],
#  ['year', 0],
#  ['imdb_link', 0],
#  ['title', 1],
#  ['Based on', 4852],
#  ['Starring', 184],
#  ['Narrated by', 6752],
#  ['Cinematography', 691],
#  ['Release date', 32],
#  ['Running time', 139],
#  ['Country', 236],
#  ['Language', 244],
#  ['Budget', 2295],
#  ['Box office', 1548],
#  ['Director', 0],
#  ['Distributor', 357],
#  ['Editor(s)', 548],
#  ['Composer(s)', 518],
#  ['Producer(s)', 202],
#  ['Production company(s)', 1678],
#  ['Writer(s)', 199],
#  ['Genre', 6923],
#  ['Original language(s)', 6875],
#  ['Original network', 6908],
#  ['Executive producer(s)', 6936],
#  ['Production location(s)', 6986],
#  ['Picture format', 6969],
#  ['Audio format', 6972],
#  ['Voices of', 7031],
#  ['Followed by', 7024],
#  ['Created by', 7023],
#  ['Preceded by', 7023],
#  ['Suggested by', 7032],
#  ['alt_titles', 7012],
#  ['Recorded', 7031],
#  ['Venue', 7032],
#  ['Label', 7031],
#  ['Animation by', 7031],
#  ['Color process', 7032],
#  ['McCune–Reischauer', 7031],
#  ['imdb_id', 0]]

# %%
[column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Based on',
#  'Starring',
#  'Cinematography',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Director',
#  'Distributor',
#  'Editor(s)',
#  'Composer(s)',
#  'Producer(s)',
#  'Production company(s)',
#  'Writer(s)',
#  'imdb_id']

# %%
wiki_columns_to_keep = [column for column in wiki_movies_df.columns if wiki_movies_df[column].isnull().sum() < len(wiki_movies_df) * 0.9]
wiki_movies_df = wiki_movies_df[wiki_columns_to_keep]

# %%
wiki_movies_df.dtypes
# Out:
# url                      object
# year                      int64
# imdb_link                object
# title                    object
# Based on                 object
# Starring                 object
# Cinematography           object
# Release date             object
# Running time             object
# Country                  object
# Language                 object
# Budget                   object
# Box office               object
# Director                 object
# Distributor              object
# Editor(s)                object
# Composer(s)              object
# Producer(s)              object
# Production company(s)    object
# Writer(s)                object
# imdb_id                  object
# dtype: object

# %%
box_office = wiki_movies_df['Box office'].dropna()

# %%
def is_not_a_string(x):
    return type(x) != str

# %%
box_office[box_office.map(is_not_a_string)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
box_office[box_office.map(lambda x: type(x) != str)]
# Out:
# 34                           [US$, 4,212,828]
# 54      [$6,698,361 (, United States, ), [2]]
# 74                    [$6,488,144, (US), [1]]
# 126                [US$1,531,489, (domestic)]
# 130                          [US$, 4,803,039]
#                         ...
# 6980               [$99.6, million, [4], [5]]
# 6994                   [$365.6, million, [1]]
# 6995                         [$53.8, million]
# 7015                     [$435, million, [7]]
# 7048                   [$529.3, million, [4]]
# Name: Box office, Length: 135, dtype: object

# %%
box_office = box_office.apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
form_one = r'\$\d+\.?\d*\s*[mb]illion'

# %%
box_office.str.contains(form_one, flags=re.IGNORECASE).sum()
# Out:
# 3896

# %%
form_two = r'\$\d{1,3}(?:,\d{3})+'
box_office.str.contains(form_two, flags=re.IGNORECASE).sum()
# Out:
# 1544

# %%
matches_form_one = box_office.str.contains(form_one, flags=re.IGNORECASE)
matches_form_two = box_office.str.contains(form_two, flags=re.IGNORECASE)

# %%
box_office[~matches_form_one & ~matches_form_two]
# Out:
# 34                         US$ 4,212,828
# 79                              $335.000
# 110                   $4.35-4.37 million
# 130                        US$ 4,803,039
# 600                           $5000 (US)
# 731                         $ 11,146,270
# 957                             $ 50,004
# 1070                          35,254,617
# 1147    $ 407,618 (U.S.) (sub-total) [1]
# 1446                        $ 11,829,959
# 1480                          £3 million
# 1611                            $520.000
# 1865                        ¥1.1 billion
# 2032                                 N/A
# 2091                                $309
# 2130               US$ 171.8 million [9]
# 2257                   US$ 3,395,581 [1]
# 2263            $ 1,223,034 ( domestic )
# 2347                            $282.175
# 2638            $ 104,883 (US sub-total)
# 2665         926,423 admissions (France)
# 2697      $ 1.7 million (US) (sub-total)
# 2823                            $414.000
# 2924                            $621.000
# 3088           $32 [2] –33.1 million [1]
# 3631                                 TBA
# 3859                  $38.9–40.3 million
# 3879            CN¥3.650 million (China)
# 4116                          £7,385,434
# 4123                            $161.000
# 4261                  $20.7–23.9 million
# 4306                              $20-30
# 4492                        $47.7 millon
# 4561             $45.2k (only in Turkey)
# 4662                USD$ 8.2 million [2]
# 5362                   $ 142 million [3]
# 5447                               £2.56
# 5784                            413 733$
# 6013                             Unknown
# 6145                  $17.5–18.4 million
# 6234                  $41.8–41.9 million
# 6369                               $111k
# 6370                                $588
# 6593                      less than $372
# 6829                    $ 41 million [3]
# 6843                             8 crore
# 6904                         $6.9 millon
# Name: Box office, dtype: object

# %%
form_one = r'\$\s*\d+\.?\d*\s*[mb]illi?on'
form_two = r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)'

# %%
box_office = box_office.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %%
box_office.str.extract(f'({form_one}|{form_two})')
# Out:
#                   0
# 0     $21.4 million
# 1      $2.7 million
# 2       $57,718,089
# 3        $7,331,647
# 4        $6,939,946
# ...             ...
# 7070  $19.4 million
# 7071  $41.9 million
# 7072  $76.1 million
# 7073  $38.4 million
# 7074   $5.5 million
#
# [5485 rows x 1 columns]

# %%
def parse_dollars(s):
    # if s is not a string, return NaN
    if type(s) != str:
        return np.nan

    # if input is of the form $###.# million
    if re.match(r'\$\s*\d+\.?\d*\s*milli?on', s, flags=re.IGNORECASE):
        
        # remove dollar sign and " million"
        s = re.sub('\$|\s|[a-zA-Z]','', s)
        
        # convert to float and multiply by a million
        value = float(s) * 10**6
        
        # return value
        return value
    
    # if input is of the form $###.# billion
    elif re.match(r'\$\s*\d+\.?\d*\s*billi?on', s, flags=re.IGNORECASE):
        
        # remove dollar sign and " billion"
        s = re.sub('\$|\s|[a-zA-Z]','', s)
        
        # convert to float and multiply by a billion
        value = float(s) * 10**9
        
        # return value
        return value
    
    # if input is of the form $###,###,###
    elif re.match(r'\$\s*\d{1,3}(?:[,\.]\d{3})+(?!\s[mb]illion)', s, flags=re.IGNORECASE):
        
        # remove dollar sign and commas
        s = re.sub('\$|,','', s)
        
        # convert to float
        value = float(s)
        
        # return value
        return value
    
    # otherwise, return NaN
    else:
        return np.nan

# %%
wiki_movies_df['box_office'] = box_office.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

# %%
wiki_movies_df['box_office']
# Out:
# 0       21400000.0
# 1        2700000.0
# 2       57718089.0
# 3        7331647.0
# 4        6939946.0
#            ...
# 7071    41900000.0
# 7072    76100000.0
# 7073    38400000.0
# 7074     5500000.0
# 7075           NaN
# Name: box_office, Length: 7033, dtype: float64

# %%
wiki_movies_df.drop('Box office', axis=1, inplace=True)

# %%
budget = wiki_movies_df['Budget'].dropna()

# %%
budget = budget.map(lambda x: ' '.join(x) if type(x) == list else x)
budget = budget.str.replace(r'\$.*[-—–](?![a-z])', '$', regex=True)

# %%
matches_form_one = budget.str.contains(form_one, flags=re.IGNORECASE)
matches_form_two = budget.str.contains(form_two, flags=re.IGNORECASE)
budget[~matches_form_one & ~matches_form_two]
# Out:
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 973             $34 [3] [4] million
# 1126               $120 [4] million
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3360               $150 [6] million
# 3418                        $218.32
# 3802                   £4.2 million
# 3906                            N/A
# 3959                    760,000 USD
# 4470                       19 crore
# 4641                    £17 million
# 5034              $$200 [4] million
# 5055           $155 [2] [3] million
# 5419                $40 [4] million
# 5424                            N/A
# 5447                     £4 million
# 5671                    €14 million
# 5687                   $ dead link]
# 6385               £ 12 million [3]
# 6593                     £3 million
# 6821                  £12.9 million
# 6843                      3.5 crore
# 6895                        919,000
# 6904                    $8.6 millon
# 7070                   €4.3 million
# Name: Budget, dtype: object

# %%
budget = budget.str.replace(r'\[\d+\]\s*', '')
budget[~matches_form_one & ~matches_form_two]
# Out:
# 136                         Unknown
# 204     60 million Norwegian Kroner
# 478                         Unknown
# 973                     $34 million
# 1126                   $120 million
# 1226                        Unknown
# 1278                            HBO
# 1374                     £6,000,000
# 1397                     13 million
# 1480                   £2.8 million
# 1734                   CAD2,000,000
# 1913     PHP 85 million (estimated)
# 1948                    102,888,900
# 1953                   3,500,000 DM
# 1973                     ₤2,300,874
# 2281                     $14 milion
# 2451                     ₤6,350,000
# 3144                   € 40 million
# 3360                   $150 million
# 3418                        $218.32
# 3802                   £4.2 million
# 3906                            N/A
# 3959                    760,000 USD
# 4470                       19 crore
# 4641                    £17 million
# 5034                  $$200 million
# 5055                   $155 million
# 5419                    $40 million
# 5424                            N/A
# 5447                     £4 million
# 5671                    €14 million
# 5687                   $ dead link]
# 6385                  £ 12 million
# 6593                     £3 million
# 6821                  £12.9 million
# 6843                      3.5 crore
# 6895                        919,000
# 6904                    $8.6 millon
# 7070                   €4.3 million
# Name: Budget, dtype: object

# %%
wiki_movies_df['budget'] = budget.str.extract(f'({form_one}|{form_two})', flags=re.IGNORECASE)[0].apply(parse_dollars)

# %%
wiki_movies_df.drop('Budget', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-926940edb8cb> in <module>
# ----> 1 wiki_movies_df.drop('Budget', axis=1, inplace=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4168             level=level,
#    4169             inplace=inplace,
# -> 4170             errors=errors,
#    4171         )
#    4172
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['Budget'] not found in axis"

# %%
release_date = wiki_movies_df['Release date'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)

# %%
date_form_one = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s[123]\d,\s\d{4}'
date_form_two = r'\d{4}.[01]\d.[123]\d'
date_form_three = r'(?:January|February|March|April|May|June|July|August|September|October|November|December)\s\d{4}'
date_form_four = r'\d{4}'

# %%
release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})', flags=re.IGNORECASE)
# Out:
#                       0
# 0         July 11, 1990
# 1          May 17, 1990
# 2       August 10, 1990
# 3     December 25, 1990
# 4     December 19, 1990
# ...                 ...
# 7071  December 25, 2018
# 7072  December 11, 2018
# 7073               2018
# 7074    August 31, 2018
# 7075      December 2018
#
# [7001 rows x 1 columns]

# %%
wiki_movies_df['release_date'] = pd.to_datetime(release_date.str.extract(f'({date_form_one}|{date_form_two}|{date_form_three}|{date_form_four})')[0], infer_datetime_format=True)
# Out:
# 0      1990-07-11
# 1      1990-05-17
# 2      1990-08-10
# 3      1990-12-25
# 4      1990-12-19
#           ...
# 7071   2018-12-25
# 7072   2018-12-11
# 7073   2018-01-01
# 7074   2018-08-31
# 7075   2018-12-01
# Name: release_date, Length: 7033, dtype: datetime64[ns]

# %%
running_time = wiki_movies_df['Running time'].dropna().apply(lambda x: ' '.join(x) if type(x) == list else x)
running_time
# Out:
# 0                                 102 minutes
# 1                                 114 minutes
# 2                                 113 minutes
# 3                                 106 minutes
# 4                                  95 minutes
#                         ...
# 7071                               90 minutes
# 7072                              132 minutes
# 7073                              120 minutes
# 7074                              123 minutes
# 7075    Variable; 90 minutes for default path
# Name: Running time, Length: 6894, dtype: object

# %%
running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE).sum()
# Out:
# 6528

# %%
running_time[running_time.str.contains(r'^\d*\s*minutes$', flags=re.IGNORECASE) != True]
# Out:
# 9                                                 102 min
# 26                                                 93 min
# 28                                                32 min.
# 34                                                101 min
# 35                                                 97 min
#                               ...
# 6500       114 minutes [1] 120 minutes (extended edition)
# 6643                                             104 mins
# 6709    90 minutes (theatrical) [1] 91 minutes (unrate...
# 7057    108 minutes (Original cut) 98 minutes (UK cut)...
# 7075                Variable; 90 minutes for default path
# Name: Running time, Length: 366, dtype: object

# %%
running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE).sum()
# Out:
# 6877

# %%
running_time[running_time.str.contains(r'^\d*\s*m', flags=re.IGNORECASE) != True]
# Out:
# 668                     UK:84 min (DVD version) US:86 min
# 727                         78-102 min (depending on cut)
# 840                       Varies (79 [3] –84 [1] minutes)
# 1347                                              25 : 03
# 1443    United States: 77 minutes Argentina: 94 minute...
# 1499                                            1hr 35min
# 1551                                               varies
# 1774                    Netherlands:96 min, Canada:95 min
# 1777                                       approx. 14 min
# 2273                                           1 h 43 min
# 2993                                               1h 48m
# 3925                                              4 hours
# 4425    US domestic version: 86 minutes Original versi...
# 4967    Theatrical cut: 97 minutes Unrated cut: 107 mi...
# 5424                    115 [1] /123 [2] /128 [3] minutes
# 5447                                    1 hour 32 minutes
# 7075                Variable; 90 minutes for default path
# Name: Running time, dtype: object

# %%
running_time_extract = running_time.str.extract(r'(\d+)\s*ho?u?r?s?\s*(\d*)|(\d+)\s*m')

# %%
running_time_extract = running_time_extract.apply(lambda col: pd.to_numeric(col, errors='coerce')).fillna(0)

# %%
wiki_movies_df['running_time'] = running_time_extract.apply(lambda row: row[0]*60 + row[1] if row[2] == 0 else row[2], axis=1)

# %%
wiki_movies_df.drop('Running time', axis=1, inplace=True)
